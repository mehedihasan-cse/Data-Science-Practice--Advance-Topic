# %% [markdown]
# <a href="https://colab.research.google.com/github/mehedihasan-cse/Data-Science-Practice--Advance-Topic/blob/main/Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data_dic = {'A':[21,np.nan,22,4,np.nan],
            'B':[31,32,33,34,35],
            'C':[np.nan,np.nan,np.nan,np.nan,np.nan],
            'D':[46,47,np.nan,48,49]}
df = pd.DataFrame(data_dic)
df
# Out:
#       A   B   C     D
# 0  21.0  31 NaN  46.0
# 1   NaN  32 NaN  47.0
# 2  22.0  33 NaN   NaN
# 3   4.0  34 NaN  48.0
# 4   NaN  35 NaN  49.0

# %%
df.isnull().sum()
# Out:
# A    2
# B    0
# C    5
# D    1
# dtype: int64

# %%
df.fillna(method='ffill')
# Out:
#       A   B   C     D
# 0  21.0  31 NaN  46.0
# 1  21.0  32 NaN  47.0
# 2  22.0  33 NaN  47.0
# 3   4.0  34 NaN  48.0
# 4   4.0  35 NaN  49.0

# %%
df.fillna(method='bfill')
# Out:
#       A   B   C     D
# 0  21.0  31 NaN  46.0
# 1  22.0  32 NaN  47.0
# 2  22.0  33 NaN  48.0
# 3   4.0  34 NaN  48.0
# 4   NaN  35 NaN  49.0

# %%
df.fillna(0)
# Out:
#       A   B    C     D
# 0  21.0  31  0.0  46.0
# 1   0.0  32  0.0  47.0
# 2  22.0  33  0.0   0.0
# 3   4.0  34  0.0  48.0
# 4   0.0  35  0.0  49.0
